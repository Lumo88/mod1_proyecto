# %% [markdown]
# **PROGRAMACIÓN JUEGO CLÁSICO - PIEDRA, PAPEL O TIJERA**

# %% [markdown]
# -----------------------

# %% [markdown]
# Paso 1: (Creación de variables)
# Igualamos las variables a 0 porque la partida va a comenzar. (Es lo lógico y correcto)
# Paso 2: (import random + creación de lista(opciones_palabras) + random.choice(opciones_palabras))
# Escribo el codigo import random el cual implica decirle a Python: "Abre la caja de herramientas al azar"
# Posteriormente, debo decirle que coga una herramienta de la caja --> Para ello usamos random.choice(opciones_palabras)
# Paso 3: (while)
# Utilizamos el while para que se respete la cantidad de rondas a jugar
# Paso 4: (Comienzo de la ronda)
# Puesto que la ronda es = 0, le sumamos 1 para dar comienzo a la ronda $DUDA$ -> ronda_1=ronda + 1?????
# Paso 5: (Uso de input() y uso de .lower())
# El input permite escoger al jugador con que "Arma" va a jugar y hacemos uso del lower para respetar la sintaxis la cual es muy importante
# Paso 6: (if,elif,else)
# if: si pasa esto...
# elif: si no pasa eso, pero pasa esto otro...
# else: si no es nada de lo anterior

# %% [markdown]
# Cosas a mejorar (ANA):
# - Poner emoticonos, mayúsculas en lugares estratégicos mediante "print()"
# - POner líneas para separar las rondas mediante "print()"

# %%
def jugar_piedra_papel_tijera():

    ronda = 0 # Variables iniciales cada vez que comienza la partida
    puntos_jugador = 0
    puntos_maquina = 0

    import random # Activamos la función 'aleatoria' para que la máquina pueda jugar
    opciones_palabras = ["piedra", "papel", "tijera"] # Fijamos una lista con las únicas palabras necesrias para jugar

    print( "🎮🪨📄✂️ BIENVENID@ AL CLÁSICO JUEGO DE PIEDRA, PAPEL O TIJERA 🎮🪨📄✂️") 

    print("🔥Prepárate para empezar, tendrás 3 rondas🔥")


    while ronda < 3: # Bucle princicpal del juego --> Comenzamos con el juego, para saber si comienza la ronda o no --> Hay < 3 rondas, por lo tanto, la partida continúa 

        palabra_jugador = input("Elige 'Piedra🪨', 'Papel📄' o 'Tijera✂️' para jugar en esta ronda").lower() # El jugador elige una opción de la lista existente

        if palabra_jugador not in opciones_palabras: # En el caso de que el jugador no escriba correctamente alguna palabra de la lista, tendrá que volverlo a escribir hasta que la escriba bien
            print(f"La palabra que has elegido: {palabra_jugador} no es válida, vuelve a elegir entre 'Piedra', 'Papel' o 'Tijera")
            continue
        
        ronda += 1 # Contador de rondas
       
        if ronda == 3: # Título de las rondas
            print("--------------------------------------------------------------------------------")
            print("RONDA FINAL")
        else:
            print("--------------------------------------------------------------------------------")
            print(f"RONDA {ronda}") 
           
        print(f"La palabra que has elegido como jugador es: {palabra_jugador}")
               
        palabra_maquina = random.choice(opciones_palabras) # La máquina elige una opción de manera aleatoria de la lista existente
        print(f"La palabra que ha elegido la máquina es: {palabra_maquina}")

        if palabra_jugador == palabra_maquina: # Condicional 1: Comparamos las palabras elegidas de cada jugador, para determinar al ganador de cada ronda de la partida
            print("¡EMPATE!🤝") # Empate y se vuelve a iniciar la ronda

        elif (palabra_jugador == "piedra🪨" and palabra_maquina == "tijera✂️") or (palabra_jugador == "tijera✂️" and palabra_maquina == "papel📄") or (palabra_jugador == "papel📄" and palabra_maquina == "piedra🪨"):
            print("¡El jugador ha ganado!👤") # El 'jugador' gana, se suma el punto del 'jugador' y se vuelve a iniciar la ronda
            puntos_jugador += 1

        else:
            print("¡La máquina ha ganado!🤖") # La 'máquina' gana, se suma el punto de la 'máquina' y se vuelve a iniciar la ronda
            puntos_maquina += 1
        
        print(f"Marcador --> Jugador👤: {puntos_jugador} / Máquina🤖: {puntos_maquina}") # Mostramos los puntos de cada jugador por cada ronda
        
    if puntos_jugador > puntos_maquina: # Hay = 3 rondas, por lo tanto, la partida finaliza y se determina al ganador de la partida
        print("El jugador ha ganado la partida 🎉👤")

    elif puntos_jugador < puntos_maquina:
        print("La máquina ha ganado la partida 🎉🤖")

    else:
        print("Es un empate🤝")

    print("🎉¡Gracias por jugar a Piedra 🪨 Papel 📄 o Tijera ✂️! Esperamos verte pronto de nuevo 🎮😄")

# %%
jugar_piedra_papel_tijera()
# Out:
# 🎮🪨📄✂️ BIENVENID@ AL CLÁSICO JUEGO DE PIEDRA, PAPEL O TIJERA 🎮🪨📄✂️
# 🔥Prepárate para empezar, tendrás 3 rondas🔥
# --------------------------------------------------------------------------------
# RONDA 1
# La palabra que has elegido como jugador es: papel
# La palabra que ha elegido la máquina es: tijera
# ¡La máquina ha ganado!🤖
# Marcador --> Jugador👤: 0 / Máquina🤖: 1
# --------------------------------------------------------------------------------
# RONDA 2
# La palabra que has elegido como jugador es: tijera
# La palabra que ha elegido la máquina es: papel
# ¡La máquina ha ganado!🤖
# Marcador --> Jugador👤: 0 / Máquina🤖: 2
# --------------------------------------------------------------------------------
# RONDA FINAL
# La palabra que has elegido como jugador es: papel
# La palabra que ha elegido la máquina es: tijera
# ¡La máquina ha ganado!🤖
# Marcador --> Jugador👤: 0 / Máquina🤖: 3
# La máquina ha ganado la partida 🎉🤖
# 🎉¡Gracias por jugar a Piedra 🪨 Papel 📄 o Tijera ✂️! Esperamos verte pronto de nuevo 🎮😄
