# %% [markdown]
# PROGRAMACIÓN JUEGO "PIEDRA, PAPEL O TIJERA"

# %%
#Variables iniciales
ronda = 0
puntos_jugador = 0
puntos_maquina = 0

palabra_jugador = 1
palabra_maquina = 1

# %%
#Condicional
if ronda <= 3:
    ronda = ronda + 1


    
    if palabra_jugador == palabra_maquina:
        print("empate")
    elif palabra_jugador == piedra and palabra_maquina == tijera or 
    palabra_jugador == tijera and palabra_maquina == papel or
    palabra_jugador == papel and palabra_maquina == piedra
     print("el jugador ha ganado")

    else:
        print("la maquina ha ganado")
# Out:
#   Cell In[24], line 9
#     elif palabra_jugador == piedra and palabra_maquina == tijera or
#                                                                     ^
# SyntaxError: invalid syntax

# %%
#Condicional
if ronda <= 3:
    ronda = ronda + 1


    
    if palabra_jugador == palabra_maquina:
        print("empate")
    elif palabra_jugador == piedra and palabra_maquina == tijera:
        print("el jugador ha ganado")
    elif palabra_jugador == tijera and palabra_maquina == papel:
        print("el jugador ha ganado")
    elif palabra_jugador == tijera and palabra_maquina == papel:
        print("el jugador ha ganado")
    else:
        print("la maquina ha ganado")
# Out:
# empate
